# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #Series for 1-Dimensional Data

# %%
sr = pd.Series(np.random.randint(10,99,50), index=['std{}'.format(i) for i in range(50)])

# %%
sr
# Out:
# std0     12
# std1     46
# std2     25
# std3     26
# std4     87
# std5     20
# std6     31
# std7     56
# std8     13
# std9     86
# std10    22
# std11    59
# std12    42
# std13    38
# std14    77
# std15    63
# std16    12
# std17    82
# std18    29
# std19    88
# std20    45
# std21    62
# std22    76
# std23    77
# std24    85
# std25    21
# std26    74
# std27    59
# std28    67
# std29    86
# std30    16
# std31    71
# std32    78
# std33    81
# std34    29
# std35    54
# std36    68
# std37    22
# std38    40
# std39    41
# std40    17
# std41    19
# std42    31
# std43    82
# std44    38
# std45    85
# std46    94
# std47    30
# std48    21
# std49    92
# dtype: int32

# %%
rd  = pd.Series(np.random.randint(10,99,50))

# %%
rd.head(10)
# Out:
# 0    67
# 1    61
# 2    23
# 3    71
# 4    61
# 5    72
# 6    79
# 7    49
# 8    12
# 9    81
# dtype: int32

# %%
rd.index=['std{}'.format(i) for i in range(50)]

# %%
rd
# Out:
# std0     67
# std1     61
# std2     23
# std3     71
# std4     61
# std5     72
# std6     79
# std7     49
# std8     12
# std9     81
# std10    32
# std11    43
# std12    26
# std13    46
# std14    52
# std15    48
# std16    27
# std17    82
# std18    29
# std19    21
# std20    43
# std21    36
# std22    50
# std23    10
# std24    78
# std25    67
# std26    64
# std27    55
# std28    94
# std29    81
# std30    12
# std31    74
# std32    58
# std33    53
# std34    55
# std35    64
# std36    17
# std37    31
# std38    17
# std39    20
# std40    30
# std41    27
# std42    93
# std43    98
# std44    90
# std45    69
# std46    39
# std47    65
# std48    75
# std49    74
# dtype: int32

# %%
# Dataframes for 2-Dimensional Data

# %%
df = pd.DataFrame(np.random.randint(10,99,50).reshape(10,5),
                 index=['row{}'.format(i) for i in range(10)],
                 columns=['Column{}'.format(i) for i in range(5)])
df
# Out:
#       Column0  Column1  Column2  Column3  Column4
# row0       53       80       60       57       21
# row1       72       54       12       46       65
# row2       53       17       78       75       78
# row3       33       27       36       93       60
# row4       40       98       46       97       92
# row5       31       73       59       22       39
# row6       17       69       53       75       17
# row7       50       27       19       68       53
# row8       63       62       77       61       70
# row9       39       15       20       56       15

# %%
df.columns
# Out:
# Index(['Column0', 'Column1', 'Column2', 'Column3', 'Column4'], dtype='object')

# %%
df.values
# Out:
# array([[53, 80, 60, 57, 21],
#        [72, 54, 12, 46, 65],
#        [53, 17, 78, 75, 78],
#        [33, 27, 36, 93, 60],
#        [40, 98, 46, 97, 92],
#        [31, 73, 59, 22, 39],
#        [17, 69, 53, 75, 17],
#        [50, 27, 19, 68, 53],
#        [63, 62, 77, 61, 70],
#        [39, 15, 20, 56, 15]])

# %%
df.index
# Out:
# Index(['row0', 'row1', 'row2', 'row3', 'row4', 'row5', 'row6', 'row7', 'row8',
#        'row9'],
#       dtype='object')

# %%
df.shape
# Out:
# (10, 5)

# %%
df.Column2
# Out:
# row0    60
# row1    12
# row2    78
# row3    36
# row4    46
# row5    59
# row6    53
# row7    19
# row8    77
# row9    20
# Name: Column2, dtype: int32

# %%
df['Column2']
# Out:
# row0    60
# row1    12
# row2    78
# row3    36
# row4    46
# row5    59
# row6    53
# row7    19
# row8    77
# row9    20
# Name: Column2, dtype: int32

# %%
df[['Column2', 'Column0','Column3']]
# Out:
#       Column2  Column0  Column3
# row0       60       53       57
# row1       12       72       46
# row2       78       53       75
# row3       36       33       93
# row4       46       40       97
# row5       59       31       22
# row6       53       17       75
# row7       19       50       68
# row8       77       63       61
# row9       20       39       56

# %%
#slicing the dataframe(iloc and loc)

# %%
df.iloc[3:7,2:4]
# Out:
#       Column2  Column3
# row3       36       93
# row4       46       97
# row5       59       22
# row6       53       75

# %%
df.loc['row2':'row9','Column2':'Column4']
# Out:
#       Column2  Column3  Column4
# row2       78       75       78
# row3       36       93       60
# row4       46       97       92
# row5       59       22       39
# row6       53       75       17
# row7       19       68       53
# row8       77       61       70
# row9       20       56       15

# %%
school_df = pd.read_csv('middle_tn_schools.csv')

# %%
school_df
# Out:
#                              name  school_rating  size  reduced_lunch  \
# 0     Allendale Elementary School              5   851             10
# 1             Anderson Elementary              2   412             71
# 2                Avoca Elementary              4   482             43
# 3                   Bailey Middle              0   394             91
# 4             Barfield Elementary              4   948             26
# ..                            ...            ...   ...            ...
# 342  Winfree Bryant Middle School              3   611             57
# 343    Winstead Elementary School              5   515              8
# 344           Woodland Elementary              4   424             55
# 345        Woodland Middle School              5   866              2
# 346                 Wright Middle              0   829             89
#
#      state_percentile_16  state_percentile_15  stu_teach_ratio    school_type  \
# ...

# %%
school_df.shape
# Out:
# (347, 15)

# %%
school_df.dtypes
# Out:
# name                    object
# school_rating            int64
# size                     int64
# reduced_lunch            int64
# state_percentile_16    float64
# state_percentile_15    float64
# stu_teach_ratio        float64
# school_type             object
# avg_score_15           float64
# avg_score_16           float64
# full_time_teachers       int64
# percent_black          float64
# percent_white          float64
# percent_asian          float64
# percent_hispanic       float64
# dtype: object

# %%
school_df.state_percentile_16
# Out:
# 0      90.2
# 1      32.8
# 2      78.4
# 3       1.6
# 4      85.3
#        ...
# 342    59.1
# 343    93.9
# 344    84.8
# 345    93.3
# 346     4.5
# Name: state_percentile_16, Length: 347, dtype: float64

# %%
school_df.full_time_teachers
# Out:
# 0      54
# 1      32
# 2      29
# 3      30
# 4      64
#        ..
# 342    36
# 343    36
# 344    30
# 345    45
# 346    50
# Name: full_time_teachers, Length: 347, dtype: int64

# %%
type(school_df.full_time_teachers)
# Out:
# pandas.core.series.Series

# %%
type(school_df.iloc[5,:])
# Out:
# pandas.core.series.Series

# %%
school_df.iloc[5,:]
# Out:
# name                   Barkers Mill Elementary School
# school_rating                                       4
# size                                              893
# reduced_lunch                                      48
# state_percentile_16                              78.1
# state_percentile_15                              76.4
# stu_teach_ratio                                  13.9
# school_type                                    Public
# avg_score_15                                     69.4
# avg_score_16                                     72.3
# full_time_teachers                                 64
# percent_black                                    28.6
# percent_white                                    39.9
# percent_asian                                     2.2
# percent_hispanic                                 17.8
# Name: 5, dtype: object

# %%
ign = pd.read_csv('ign.csv')

# %%
ign.head(10)
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
# 5           5         Good                          Total War Battles: Shogun
# 6           6        Awful                                Double Dragon: Neon
# 7           7      Amazing                                       Guild Wars 2
# 8           8        Awful                                Double Dragon: Neon
# 9           9         Good                          Total War Battles: Shogun
#
#                                                  url          platform  score  \
# ...

# %%
ign.tail(10)
# Out:
#        Unnamed: 0 score_phrase  \
# 18615       18615      Amazing
# 18616       18616         Good
# 18617       18617        Great
# 18618       18618      Amazing
# 18619       18619         Good
# 18620       18620         Good
# 18621       18621      Amazing
# 18622       18622     Mediocre
# 18623       18623  Masterpiece
# 18624       18624  Masterpiece
#
#                                                    title  \
# 18615                                  Zero Time Dilemma
# 18616  Batman: The Telltale Series -- Episode 1: Real...
# 18617                                               Abzu
# 18618                                          Starbound
# 18619                                    Human Fall Flat
# 18620                          Tokyo Mirage Sessions #FE
# 18621                  LEGO Star Wars: The Force Awakens
# 18622            Star Ocean: Integrity and Faithlessness
# 18623                                             Inside
# ...

# %%
ign.sample(10)
# Out:
#        Unnamed: 0 score_phrase                                  title  \
# 1020         1020          Bad                          Rage of Mages
# 11928       11928         Good                                NBA 2K9
# 15603       15603         Good  Tom Clancy's Ghost Recon: Shadow Wars
# 2568         2568         Okay                         Hard Trucks II
# 456           456     Mediocre               The King of Fighters '95
# 17966       17966        Great         Captain Toad: Treasure Tracker
# 12244       12244         Good              Pro Evolution Soccer 2009
# 16373       16373          Bad                         NCIS: The Game
# 3927         3927      Amazing                                Deus Ex
# 5081         5081         Okay                            Pandemonium
#
#                                                      url  \
# 1020                       /games/rage-of-mages/pc-10195
# 11928                        /games/nba-2k9/ps2-14258122
# ...

# %%
ign[(ign.score_phrase == 'Amazing') & (ign.platform == 'iPad')].shape[0]
# Out:
# 18

# %%
ign[(ign.score_phrase == 'Amazing') & (ign.platform == 'iPad')]
# Out:
#        Unnamed: 0 score_phrase  \
# 26             26      Amazing
# 52             52      Amazing
# 137           137      Amazing
# 247           247      Amazing
# 328           328      Amazing
# 14329       14329      Amazing
# 14330       14330      Amazing
# 14801       14801      Amazing
# 14862       14862      Amazing
# 15065       15065      Amazing
# 15364       15364      Amazing
# 15391       15391      Amazing
# 15553       15553      Amazing
# 15604       15604      Amazing
# 16454       16454      Amazing
# 17252       17252      Amazing
# 17615       17615      Amazing
# 17697       17697      Amazing
#
#                                                    title  \
# 26                                               Bastion
# 52                   The World Ends with You: Solo Remix
# 137    The Walking Dead: The Game -- Episode 3: Long ...
# 247    The Walking Dead: The Game -- Episode 5: No Ti...
# 328    The Walking Dead: A Telltale Game Series -- Se...
# ...

# %%
ign[(ign.platform == 'iPad')].shape[0]
# Out:
# 99

# %% [markdown]
# How many games were launched after April 2014?

# %%
ign.columns
# Out:
# Index(['Unnamed: 0', 'score_phrase', 'title', 'url', 'platform', 'score',
#        'genre', 'editors_choice', 'release_year', 'release_month',
#        'release_day'],
#       dtype='object')

# %%
ign['new_col'] = ign.release_year*100 + ign.release_month

# %%
ign[ign.new_col>201404].shape[0]
# Out:
# 934

# %%
ign[ign.new_col>201404]
# Out:
#        Unnamed: 0 score_phrase                                    title  \
# 17650       17650          Bad                 The Amazing Spider-Man 2
# 17651       17651         Good                Sir, You are Being Hunted
# 17652       17652         Good   Republique -- Episode 2: Metamorphosis
# 17653       17653     Mediocre                 The Amazing Spider-Man 2
# 17654       17654     Mediocre                 The Amazing Spider-Man 2
# ...           ...          ...                                      ...
# 18620       18620         Good                Tokyo Mirage Sessions #FE
# 18621       18621      Amazing        LEGO Star Wars: The Force Awakens
# 18622       18622     Mediocre  Star Ocean: Integrity and Faithlessness
# 18623       18623  Masterpiece                                   Inside
# 18624       18624  Masterpiece                                   Inside
#
#                                                      url       platform  \
# ...

# %%
ign = ign.drop('new_col', axis=1, inplace=True)

# %%
ign.columns
# Out:
# Index(['Unnamed: 0', 'score_phrase', 'title', 'url', 'platform', 'score',
#        'genre', 'editors_choice', 'release_year', 'release_month',
#        'release_day'],
#       dtype='object')

# %%
ign
# Out:
#        Unnamed: 0 score_phrase  \
# 0               0      Amazing
# 1               1      Amazing
# 2               2        Great
# 3               3        Great
# 4               4        Great
# ...           ...          ...
# 18620       18620         Good
# 18621       18621      Amazing
# 18622       18622     Mediocre
# 18623       18623  Masterpiece
# 18624       18624  Masterpiece
#
#                                                    title  \
# 0                                LittleBigPlanet PS Vita
# 1      LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                                   Splice: Tree of Life
# 3                                                 NHL 13
# 4                                                 NHL 13
# ...                                                  ...
# 18620                          Tokyo Mirage Sessions #FE
# 18621                  LEGO Star Wars: The Force Awakens
# 18622            Star Ocean: Integrity and Faithlessness
# ...

# %%
ign.title.str.lower()
# Out:
# 0                                  littlebigplanet ps vita
# 1        littlebigplanet ps vita -- marvel super hero e...
# 2                                     splice: tree of life
# 3                                                   nhl 13
# 4                                                   nhl 13
#                                ...
# 18620                            tokyo mirage sessions #fe
# 18621                    lego star wars: the force awakens
# 18622              star ocean: integrity and faithlessness
# 18623                                               inside
# 18624                                               inside
# Name: title, Length: 18625, dtype: object

# %%
ign.title.str.upper()
# Out:
# 0                                  LITTLEBIGPLANET PS VITA
# 1        LITTLEBIGPLANET PS VITA -- MARVEL SUPER HERO E...
# 2                                     SPLICE: TREE OF LIFE
# 3                                                   NHL 13
# 4                                                   NHL 13
#                                ...
# 18620                            TOKYO MIRAGE SESSIONS #FE
# 18621                    LEGO STAR WARS: THE FORCE AWAKENS
# 18622              STAR OCEAN: INTEGRITY AND FAITHLESSNESS
# 18623                                               INSIDE
# 18624                                               INSIDE
# Name: title, Length: 18625, dtype: object

# %%
ign.title.str.split(' ')
# Out:
# 0                              [LittleBigPlanet, PS, Vita]
# 1        [LittleBigPlanet, PS, Vita, --, Marvel, Super,...
# 2                                [Splice:, Tree, of, Life]
# 3                                                [NHL, 13]
# 4                                                [NHL, 13]
#                                ...
# 18620                       [Tokyo, Mirage, Sessions, #FE]
# 18621             [LEGO, Star, Wars:, The, Force, Awakens]
# 18622        [Star, Ocean:, Integrity, and, Faithlessness]
# 18623                                             [Inside]
# 18624                                             [Inside]
# Name: title, Length: 18625, dtype: object

# %%
ign.title.str.find(' ')
# Out:
# 0        15
# 1        15
# 2         7
# 3         3
# 4         3
#          ..
# 18620     5
# 18621     4
# 18622     4
# 18623    -1
# 18624    -1
# Name: title, Length: 18625, dtype: int64

# %%
ign.title.str.count(' ')
# Out:
# 0        2
# 1        7
# 2        3
# 3        1
# 4        1
#         ..
# 18620    3
# 18621    5
# 18622    4
# 18623    0
# 18624    0
# Name: title, Length: 18625, dtype: int64

# %%
ign.title.str.len()
# Out:
# 0        23
# 1        52
# 2        20
# 3         6
# 4         6
#          ..
# 18620    25
# 18621    33
# 18622    39
# 18623     6
# 18624     6
# Name: title, Length: 18625, dtype: int64

# %%
ign.title.str[:5]
# Out:
# 0        Littl
# 1        Littl
# 2        Splic
# 3        NHL 1
# 4        NHL 1
#          ...
# 18620    Tokyo
# 18621    LEGO
# 18622    Star
# 18623    Insid
# 18624    Insid
# Name: title, Length: 18625, dtype: object

# %%
ign.title.str.replace(' ','_')
# Out:
# 0                                  LittleBigPlanet_PS_Vita
# 1        LittleBigPlanet_PS_Vita_--_Marvel_Super_Hero_E...
# 2                                     Splice:_Tree_of_Life
# 3                                                   NHL_13
# 4                                                   NHL_13
#                                ...
# 18620                            Tokyo_Mirage_Sessions_#FE
# 18621                    LEGO_Star_Wars:_The_Force_Awakens
# 18622              Star_Ocean:_Integrity_and_Faithlessness
# 18623                                               Inside
# 18624                                               Inside
# Name: title, Length: 18625, dtype: object

# %%
ign.title
# Out:
# 0                                  LittleBigPlanet PS Vita
# 1        LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                                     Splice: Tree of Life
# 3                                                   NHL 13
# 4                                                   NHL 13
#                                ...
# 18620                            Tokyo Mirage Sessions #FE
# 18621                    LEGO Star Wars: The Force Awakens
# 18622              Star Ocean: Integrity and Faithlessness
# 18623                                               Inside
# 18624                                               Inside
# Name: title, Length: 18625, dtype: object

# %%
txt = ign.loc[2, 'title']

# %%
txt
# Out:
# 'Splice: Tree of Life'

# %%
txt.find(' ')
# Out:
# 7

# %%
txt.find(' ', txt.find(' ')+1)
# Out:
# 12

# %%
def abc(txt):
    return txt.find(' ', txt.find(' ')+1)

# %%
ign['colname'] = ign.title.apply(abc)
# Out:
# 0        18
# 1        18
# 2        12
# 3        -1
# 4        -1
#          ..
# 18620    12
# 18621     9
# 18622    11
# 18623    -1
# 18624    -1
# Name: title, Length: 18625, dtype: int64

# %%
ign
# Out:
#        Unnamed: 0 score_phrase  \
# 0               0      Amazing
# 1               1      Amazing
# 2               2        Great
# 3               3        Great
# 4               4        Great
# ...           ...          ...
# 18620       18620         Good
# 18621       18621      Amazing
# 18622       18622     Mediocre
# 18623       18623  Masterpiece
# 18624       18624  Masterpiece
#
#                                                    title  \
# 0                                LittleBigPlanet PS Vita
# 1      LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                                   Splice: Tree of Life
# 3                                                 NHL 13
# 4                                                 NHL 13
# ...                                                  ...
# 18620                          Tokyo Mirage Sessions #FE
# 18621                  LEGO Star Wars: The Force Awakens
# 18622            Star Ocean: Integrity and Faithlessness
# ...

# %%
# create a new column game_id where we will store the last element from url---pc-20055740

# %%
ign.url.str.split('/').str[-1]
# Out:
# 0             vita-98907
# 1          vita-20027059
# 2            ipad-141070
# 3        xbox-360-128182
# 4             ps3-128181
#               ...
# 18620       wii-u-158650
# 18621       ps4-20048817
# 18622       ps4-20035681
# 18623    xbox-one-121435
# 18624        pc-20055740
# Name: url, Length: 18625, dtype: object

# %%
def game_id(ls):
    return ls[-1]

# %%
ign.url.str.split('/').apply(game_id)
# Out:
# 0             vita-98907
# 1          vita-20027059
# 2            ipad-141070
# 3        xbox-360-128182
# 4             ps3-128181
#               ...
# 18620       wii-u-158650
# 18621       ps4-20048817
# 18622       ps4-20035681
# 18623    xbox-one-121435
# 18624        pc-20055740
# Name: url, Length: 18625, dtype: object

# %%
ign['game_id'] = ign.url.apply(lambda x: x.split('/')[-1])

# %%
ign
# Out:
#        Unnamed: 0 score_phrase  \
# 0               0      Amazing
# 1               1      Amazing
# 2               2        Great
# 3               3        Great
# 4               4        Great
# ...           ...          ...
# 18620       18620         Good
# 18621       18621      Amazing
# 18622       18622     Mediocre
# 18623       18623  Masterpiece
# 18624       18624  Masterpiece
#
#                                                    title  \
# 0                                LittleBigPlanet PS Vita
# 1      LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                                   Splice: Tree of Life
# 3                                                 NHL 13
# 4                                                 NHL 13
# ...                                                  ...
# 18620                          Tokyo Mirage Sessions #FE
# 18621                  LEGO Star Wars: The Force Awakens
# 18622            Star Ocean: Integrity and Faithlessness
# ...

# %%
# Qualitative Ananlysis

# %%
ign.score_phrase.nunique()
# Out:
# 11

# %%
ign.score_phrase.unique()
# Out:
# array(['Amazing', 'Great', 'Good', 'Awful', 'Okay', 'Mediocre', 'Bad',
#        'Painful', 'Unbearable', 'Disaster', 'Masterpiece'], dtype=object)

# %%
ign.score_phrase.value_counts()
# Out:
# Great          4773
# Good           4741
# Okay           2945
# Mediocre       1959
# Amazing        1804
# Bad            1269
# Awful           664
# Painful         340
# Unbearable       72
# Masterpiece      55
# Disaster          3
# Name: score_phrase, dtype: int64

# %%
# In which year most number of games were launched

# %%
ign.release_year.value_counts()
# Out:
# 2008    1915
# 2009    1687
# 2007    1610
# 2010    1363
# 2006    1208
# 2005    1088
# 2011    1073
# 2000    1045
# 2004     997
# 2003     969
# 2002     936
# 1999     775
# 2012     753
# 2013     696
# 2001     688
# 2014     537
# 2015     365
# 1998     339
# 2016     226
# 1997     205
# 1996     149
# 1970       1
# Name: release_year, dtype: int64

# %%
for year in ign.release_year.unique():
    print(year, ign[ign.release_year == year].title.nunique())
# Out:
# 2012 498
# 2013 411
# 1996 134
# 1970 1
# 1997 200
# 1998 306
# 1999 675
# 2000 888
# 2001 602
# 2002 702
# 2003 700
# 2004 734
# 2005 759
# 2006 839
# 2007 1169
# 2008 1384
# 2009 1186
# 2010 1015
# 2011 780
# 2014 316
# 2015 261
# 2016 174

# %%
ign.describe()
# Out:
#          Unnamed: 0         score  release_year  release_month   release_day
# count  18625.000000  18625.000000  18625.000000    18625.00000  18625.000000
# mean    9312.000000      6.950459   2006.515329        7.13847     15.603866
# std     5376.718717      1.711736      4.587529        3.47671      8.690128
# min        0.000000      0.500000   1970.000000        1.00000      1.000000
# 25%     4656.000000      6.000000   2003.000000        4.00000      8.000000
# 50%     9312.000000      7.300000   2007.000000        8.00000     16.000000
# 75%    13968.000000      8.200000   2010.000000       10.00000     23.000000
# max    18624.000000     10.000000   2016.000000       12.00000     31.000000

# %%
ign.score.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>
